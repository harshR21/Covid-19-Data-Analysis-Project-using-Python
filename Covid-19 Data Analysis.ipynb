# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("C:/Users/Harsh/Downloads/cov.csv.csv")

# %%
data.()
# Out:
#   Province/State         Country Date last updated  Confirmed  Suspected  \
# 0       Shanghai  Mainland China         1/21/2020        9.0       10.0
# 1         Yunnan  Mainland China         1/21/2020        1.0        NaN
# 2        Beijing  Mainland China         1/21/2020       10.0        NaN
# 3         Taiwan  Mainland China         1/21/2020        1.0        NaN
# 4          Jilin  Mainland China         1/21/2020        NaN        1.0
#
#    Recovered  Deaths
# 0        NaN     NaN
# 1        NaN     NaN
# 2        NaN     NaN
# 3        NaN     NaN
# 4        NaN     NaN

# %%
data.columns
# Out:
# Index(['Province/State', 'Country', 'Date last updated', 'Confirmed',
#        'Suspected', 'Recovered', 'Deaths'],
#       dtype='object')

# %%
data.tail()
data.isnull().sum()
# Out:
# Province/State        64
# Country                0
# Date last updated      0
# Confirmed             29
# Suspected            280
# Recovered            332
# Deaths               344
# dtype: int64

# %%
sns.relplot(x="Suspected",y="Deaths", data=data)

# %%
sns.pairplot(data)

# %%
sns.relplot(x="Suspected",y="Deaths",kind = 'line',data=data)
data.columns
# Out:
# Index(['Province/State', 'Country', 'Date last updated', 'Confirmed',
#        'Suspected', 'Recovered', 'Deaths'],
#       dtype='object')

# %%
sns.relplot(x= "Recovered" , y = "Deaths" , kind = "line" , data = data)

# %%
sns.catplot( x = "Suspected" , y = "Recovered" , data = data)

# %%
data.head()
# Out:
#   Province/State         Country Date last updated  Confirmed  Suspected  \
# 0       Shanghai  Mainland China         1/21/2020        9.0       10.0
# 1         Yunnan  Mainland China         1/21/2020        1.0        NaN
# 2        Beijing  Mainland China         1/21/2020       10.0        NaN
# 3         Taiwan  Mainland China         1/21/2020        1.0        NaN
# 4          Jilin  Mainland China         1/21/2020        NaN        1.0
#
#    Recovered  Deaths
# 0        NaN     NaN
# 1        NaN     NaN
# 2        NaN     NaN
# 3        NaN     NaN
# 4        NaN     NaN
